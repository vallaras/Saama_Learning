# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("laptops.csv",encoding=('ISO-8859-1'))

# %%
mask = df["ScreenResolution"].isin(["IPS Panel Retina Display 2560x1600",
                                  "IPS Panel Retina Display 2880x1800"])

# %%
r_str = df[mask]

# %%
r_str
# Out:
#      Unnamed: 0 Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 3             4   Apple  MacBook Pro  Ultrabook    15.4
# 4             5   Apple  MacBook Pro  Ultrabook    13.3
# 6             7   Apple  MacBook Pro  Ultrabook    15.4
# 12           13   Apple  MacBook Pro  Ultrabook    15.4
# 15           16   Apple  MacBook Pro  Ultrabook    13.3
# 17           18   Apple  MacBook Pro  Ultrabook    15.4
# 45           46   Apple  MacBook Pro  Ultrabook    13.3
# 249         254   Apple  MacBook Pro  Ultrabook    13.3
# 270         275   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 0    IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz   8GB
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 4    IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# ...

# %%
a = []
for i in r_str["ScreenResolution"]:
    n = i[25:]
    a.append(n)
test = pd.DataFrame(a)

# %%
test
# Out:
#   ScreenResolution
# 0        2560x1600
# 1        2880x1800
# 2        2560x1600
# 3        2880x1800
# 4        2880x1800
# 5        2560x1600
# 6        2880x1800
# 7        2560x1600
# 8        2560x1600
# 9        2560x1600

# %%
#test.drop(test.iloc[:, 1:3], inplace=True, axis=1)
#test_data=test.drop(['TypeName',"Inches","ScreenResolution","Cpu","Ram","Memory","Gpu","OpSys","Weight","Price_euros"], axis=1)

# %%
test.columns=['ScreenResolution']

# %%
test_data=test_data.reset_index().drop(columns='index')

# %%
len(test)
# Out:
# 10

# %%
new_data=pd.concat([test_data,test],axis=1)

# %%
new_data
# Out:
#    Unnamed: 0 Company      Product ScreenResolution
# 0           1   Apple  MacBook Pro        2560x1600
# 1           4   Apple  MacBook Pro        2880x1800
# 2           5   Apple  MacBook Pro        2560x1600
# 3           7   Apple  MacBook Pro        2880x1800
# 4          13   Apple  MacBook Pro        2880x1800
# 5          16   Apple  MacBook Pro        2560x1600
# 6          18   Apple  MacBook Pro        2880x1800
# 7          46   Apple  MacBook Pro        2560x1600
# 8         254   Apple  MacBook Pro        2560x1600
# 9         275   Apple  MacBook Pro        2560x1600

# %%
x = new_data["Company"]
y = new_data["ScreenResolution"]

# %%
plt.scatter(x, y)
 
# Adding legend to the plot
plt.legend("A")
 
# Title to the plot
plt.title("Scatter chart")
plt.show()
