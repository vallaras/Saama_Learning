# %%
from sklearn import datasets
import pandas as pd

# %%
iris=datasets.load_iris()
iris_df=pd.DataFrame(iris.data)
iris_df['class']=iris.target
print(iris_df)
# Out:
#        0    1    2    3  class
# 0    5.1  3.5  1.4  0.2      0
# 1    4.9  3.0  1.4  0.2      0
# 2    4.7  3.2  1.3  0.2      0
# 3    4.6  3.1  1.5  0.2      0
# 4    5.0  3.6  1.4  0.2      0
# ..   ...  ...  ...  ...    ...
# 145  6.7  3.0  5.2  2.3      2
# 146  6.3  2.5  5.0  1.9      2
# 147  6.5  3.0  5.2  2.0      2
# 148  6.2  3.4  5.4  2.3      2
# 149  5.9  3.0  5.1  1.8      2
#
# [150 rows x 5 columns]

# %%
iris_df.columns=['sepl_len','sepal_wind','petal_len','petal_wid','class']

# %%
iris_df.dropna(how="all",inplace=True)

# %%
iris_df
# Out:
#      sepl_len  sepal_wind  petal_len  petal_wid  class
# 0         5.1         3.5        1.4        0.2      0
# 1         4.9         3.0        1.4        0.2      0
# 2         4.7         3.2        1.3        0.2      0
# 3         4.6         3.1        1.5        0.2      0
# 4         5.0         3.6        1.4        0.2      0
# ..        ...         ...        ...        ...    ...
# 145       6.7         3.0        5.2        2.3      2
# 146       6.3         2.5        5.0        1.9      2
# 147       6.5         3.0        5.2        2.0      2
# 148       6.2         3.4        5.4        2.3      2
# 149       5.9         3.0        5.1        1.8      2
#
# [150 rows x 5 columns]

# %%
iris_df["sepl_len"].dtype
# Out:
# dtype('float64')

# %%
iris_df["sepl_len"]=iris_df["sepl_len"].astype('str')

# %%
iris_df["sepal_wind"]=iris_df["sepal_wind"].astype('str')

# %%
iris_df["petal_len"]=iris_df["petal_len"].astype('int')

# %%
iris_df
# Out:
#     sepl_len sepal_wind  petal_len  petal_wid  class
# 0        5.1        3.5          1        0.2      0
# 1        4.9        3.0          1        0.2      0
# 2        4.7        3.2          1        0.2      0
# 3        4.6        3.1          1        0.2      0
# 4        5.0        3.6          1        0.2      0
# ..       ...        ...        ...        ...    ...
# 145      6.7        3.0          5        2.3      2
# 146      6.3        2.5          5        1.9      2
# 147      6.5        3.0          5        2.0      2
# 148      6.2        3.4          5        2.3      2
# 149      5.9        3.0          5        1.8      2
#
# [150 rows x 5 columns]

# %%
iris_df["petal_wid"].dtype
# Out:
# dtype('float64')

# %%
listname=[]
for i in iris_df["petal_wid"]:
    if i>5:
        listname.append("big")
    else:
        listname.append("small")

# %%
listname
# Out:
# ['small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
#  'small',
# ...

# %%
iris_df.insert(5,column="listname",value="small")

# %%
iris_df
# Out:
#     sepl_len sepal_wind  petal_len  petal_wid  class listname
# 0        5.1        3.5          1        0.2      0    small
# 1        4.9        3.0          1        0.2      0    small
# 2        4.7        3.2          1        0.2      0    small
# 3        4.6        3.1          1        0.2      0    small
# 4        5.0        3.6          1        0.2      0    small
# ..       ...        ...        ...        ...    ...      ...
# 145      6.7        3.0          5        2.3      2    small
# 146      6.3        2.5          5        1.9      2    small
# 147      6.5        3.0          5        2.0      2    small
# 148      6.2        3.4          5        2.3      2    small
# 149      5.9        3.0          5        1.8      2    small
#
# [150 rows x 6 columns]
